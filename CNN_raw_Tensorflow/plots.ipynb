# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from PIL import Image
from scipy import interpolate
# %matplotlib inline

# Load all data
loss_adam = pd.read_csv('collected_losses_adam.csv')
acc_adam = pd.read_csv('collected_acc_adam.csv')
loss_adadel = pd.read_csv('collected_losses_adadel.csv')
acc_adadel = pd.read_csv('collected_acc_adadel.csv')
loss_adam_oversample = pd.read_csv('collected_losses_adam_oversample.csv') # Contains more steps, hence the next line
loss_adam_oversample = loss_adam_oversample.iloc[:601]
acc_adam_oversample = pd.read_csv('collected_acc_adam_oversample.csv') # Contains more steps, hence the next line
acc_adam_oversample = acc_adam_oversample.iloc[:601]
loss_adadel_oversample = pd.read_csv('collected_losses_adadel_oversample.csv')
acc_adadel_oversample = pd.read_csv('collected_acc_adadel_oversample.csv')

x_axis = [10*i for i in range(len(data.iloc[:601]))]
len(loss_adam), len(acc_adam), len(loss_adadel), len(acc_adadel), len(loss_adam_oversample), len(acc_adam_oversample), len(loss_adadel_oversample), len(acc_adadel_oversample)
loss_adam;

# %%
loss_adam_train_smooth = interpolate.UnivariateSpline(x_axis, loss_adam['train_loss'], s=5e8)(x_axis)
loss_adam_test_smooth = interpolate.UnivariateSpline(x_axis, loss_adam['test_loss'], s=5e8)(x_axis)

fig = plt.figure(figsize=(15,7))
ax = plt.subplot(111)
ax.plot(x_axis, loss_adam['train_loss'], label='Train loss')
ax.plot(x_axis, loss_adam_train_smooth, label='_nolegend_', alpha=0.4, color='black', linewidth=2)
ax.plot(x_axis, loss_adam['test_loss'], label='Test loss')
ax.plot(x_axis, loss_adam_test_smooth, label='_nolegend_', alpha=0.4, color='black',linewidth=2)
plt.title('Train and test losses using Adam Optimizer $\eta = 0.001$')
ax.legend()
plt.xlabel('Steps')
plt.ylabel('L1 loss')
 
fig.savefig('loss_adam.png')

# %%
acc_adam_train_smooth = interpolate.UnivariateSpline(x_axis, acc_adam['accuracy_train'], s=5e4)(x_axis)
acc_adam_test_smooth = interpolate.UnivariateSpline(x_axis, acc_adam['accuracy_test'], s=5e4)(x_axis)

fig = plt.figure(figsize=(15,7))
ax = plt.subplot(111)
ax.plot(x_axis, acc_adam['accuracy_train'], label='Accuracy loss')
ax.plot(x_axis, acc_adam_train_smooth, label='_nolegend_', alpha=0.4, color='black', linewidth=2)
ax.plot(x_axis, acc_adam['accuracy_test'], label='Accuracy loss')
ax.plot(x_axis, acc_adam_test_smooth, label='_nolegend_', alpha=0.4, color='black',linewidth=2)
plt.title('Train and test accuracies using Adam Optimizer $\eta = 0.001$')
ax.legend()
plt.xlabel('Steps')
plt.ylabel('Accuracy')
 
fig.savefig('acc_adam.png')

# %%
loss_adadel_train_smooth = interpolate.UnivariateSpline(x_axis, loss_adadel['train_loss'], s=5e5)(x_axis)
loss_adadel_test_smooth = interpolate.UnivariateSpline(x_axis, loss_adadel['test_loss'], s=5e4)(x_axis)

fig = plt.figure(figsize=(15,7))
ax = plt.subplot(111)
ax.plot(x_axis, loss_adadel['train_loss'], label='Train loss')
ax.plot(x_axis, loss_adadel_train_smooth, label='_nolegend_', alpha=0.4, color='black', linewidth=2)
ax.plot(x_axis, loss_adadel['test_loss'], label='Test loss')
ax.plot(x_axis, loss_adadel_test_smooth, label='_nolegend_', alpha=0.4, color='black',linewidth=2)
plt.title('Train and test losses using Adadelta Optimizer $\eta = 0.1$')
ax.legend()
plt.xlabel('Steps')
plt.ylabel('L1 loss')
 
fig.savefig('loss_adadel.png')

# %%
acc_adadel_train_smooth = interpolate.UnivariateSpline(x_axis, acc_adadel['accuracy_train'], s=5e4)(x_axis)
acc_adadel_test_smooth = interpolate.UnivariateSpline(x_axis, acc_adadel['accuracy_test'], s=5e4)(x_axis)

fig = plt.figure(figsize=(15,7))
ax = plt.subplot(111)
ax.plot(x_axis, acc_adadel['accuracy_train'], label='Accuracy loss')
ax.plot(x_axis, acc_adadel_train_smooth, label='_nolegend_', alpha=0.4, color='black', linewidth=2)
ax.plot(x_axis, acc_adadel['accuracy_test'], label='Accuracy loss')
ax.plot(x_axis, acc_adadel_test_smooth, label='_nolegend_', alpha=0.4, color='black',linewidth=2)
plt.title('Train and test accuracies using Adadelta Optimizer $\eta = 0.1$')
ax.legend()
plt.xlabel('Steps')
plt.ylabel('Accuracy')
 
fig.savefig('acc_adadel.png')

# %%
loss_adam_oversample_train_smooth = interpolate.UnivariateSpline(x_axis, loss_adam_oversample['train_loss'], s=5e8)(x_axis)
loss_adam_oversample_test_smooth = interpolate.UnivariateSpline(x_axis, loss_adam_oversample['test_loss'], s=5e8)(x_axis)

fig = plt.figure(figsize=(15,7))
ax = plt.subplot(111)
ax.plot(x_axis, loss_adam_oversample['train_loss'], label='Train loss')
ax.plot(x_axis, loss_adam_oversample_train_smooth, label='_nolegend_', alpha=0.4, color='black', linewidth=2)
ax.plot(x_axis, loss_adam_oversample['test_loss'], label='Test loss')
ax.plot(x_axis, loss_adam_oversample_test_smooth, label='_nolegend_', alpha=0.4, color='black',linewidth=2)
plt.title('Train and test losses using Adam Optimizer $\eta = 0.001$, with oversampling technique')
ax.legend()
plt.xlabel('Steps')
plt.ylabel('L1 loss')
 
fig.savefig('loss_adam_oversample.png')

# %%
acc_adam_oversample_train_smooth = interpolate.UnivariateSpline(x_axis, acc_adam_oversample['accuracy_train'], s=5e4)(x_axis)
acc_adam_oversample_test_smooth = interpolate.UnivariateSpline(x_axis, acc_adam_oversample['accuracy_test'], s=5e4)(x_axis)

fig = plt.figure(figsize=(15,7))
ax = plt.subplot(111)
ax.plot(x_axis, acc_adam_oversample['accuracy_train'], label='Accuracy loss')
ax.plot(x_axis, acc_adam_oversample_train_smooth, label='_nolegend_', alpha=0.4, color='black', linewidth=2)
ax.plot(x_axis, acc_adam_oversample['accuracy_test'], label='Accuracy loss')
ax.plot(x_axis, acc_adam_oversample_test_smooth, label='_nolegend_', alpha=0.4, color='black',linewidth=2)
plt.title('Train and test accuracies using Adam Optimizer $\eta = 0.001$, with oversampling technique')
ax.legend()
plt.xlabel('Steps')
plt.ylabel('Accuracy')
 
fig.savefig('acc_adam_oversample.png')

# %%
loss_adadel_oversample_train_smooth = interpolate.UnivariateSpline(x_axis, loss_adadel_oversample['train_loss'], s=5e8)(x_axis)
loss_adadel_oversample_test_smooth = interpolate.UnivariateSpline(x_axis, loss_adadel_oversample['test_loss'], s=5e8)(x_axis)

fig = plt.figure(figsize=(15,7))
ax = plt.subplot(111)
ax.plot(x_axis, loss_adadel_oversample['train_loss'], label='Train loss')
ax.plot(x_axis, loss_adadel_oversample_train_smooth, label='_nolegend_', alpha=0.4, color='black', linewidth=2)
ax.plot(x_axis, loss_adadel_oversample['test_loss'], label='Test loss')
ax.plot(x_axis, loss_adadel_oversample_test_smooth, label='_nolegend_', alpha=0.4, color='black',linewidth=2)
plt.title('Train and test losses using Adadelta Optimizer $\eta = 0.1$, with oversampling technique')
ax.legend()
plt.xlabel('Steps')
plt.ylabel('L1 loss')
 
fig.savefig('loss_adadel_oversample.png')

# %%
acc_adadel_oversample_train_smooth = interpolate.UnivariateSpline(x_axis, acc_adadel_oversample['accuracy_train'], s=5e4)(x_axis)
acc_adadel_oversample_test_smooth = interpolate.UnivariateSpline(x_axis, acc_adadel_oversample['accuracy_test'], s=5e4)(x_axis)

fig = plt.figure(figsize=(15,7))
ax = plt.subplot(111)
ax.plot(x_axis, acc_adadel_oversample['accuracy_train'], label='Accuracy loss')
ax.plot(x_axis, acc_adadel_oversample_train_smooth, label='_nolegend_', alpha=0.4, color='black', linewidth=2)
ax.plot(x_axis, acc_adadel_oversample['accuracy_test'], label='Accuracy loss')
ax.plot(x_axis, acc_adadel_oversample_test_smooth, label='_nolegend_', alpha=0.4, color='black',linewidth=2)
plt.title('Train and test accuracies using Adadelta Optimizer $\eta = 0.1$, with oversampling technique')
ax.legend()
plt.xlabel('Steps')
plt.ylabel('Accuracy')
 
fig.savefig('acc_adadel_oversample.png')
